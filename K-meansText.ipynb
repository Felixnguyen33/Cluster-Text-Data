# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Movies_Dataset.csv')
df
# Out:
#           id                        title  \
# 0          0                    Toy Story
# 1          1                      Jumanji
# 2          2             Grumpier Old Men
# 3          3            Waiting to Exhale
# 4          4  Father of the Bride Part II
# ...      ...                          ...
# 45461  45461                       Subdue
# 45462  45462          Century of Birthing
# 45463  45463                     Betrayal
# 45464  45464             Satan Triumphant
# 45465  45465                     Queerama
#
#                                                 overview
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45461        Rising and falling between a man and woman.
# 45462  An artist struggles to finish his work while a...
# 45463  When one of her hits goes wrong, a professiona...
# 45464  In a small town live two brothers, one a minis...
# 45465  50 years after decriminalisation of homosexual...
#
# [45466 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

documents = df['overview'].values.astype("U")
vectorizer = TfidfVectorizer( stop_words='english')
features = vectorizer.fit_transform(documents)

features
# Out:
# <45466x74567 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1212061 stored elements in Compressed Sparse Row format>

# %%
print(features)
# Out:
#   (0, 38029)	0.10739705953465474
#   (0, 73094)	0.4809827114790238
#   (0, 3554)	0.4117836571172595
#   (0, 67545)	0.14878284660693247
#   (0, 38963)	0.0871868917895906
#   (0, 28809)	0.13311522181618415
#   (0, 56644)	0.11124851086523602
#   (0, 7838)	0.12380553184830105
#   (0, 9430)	0.10635375129287979
#   (0, 10204)	0.502803868613561
#   (0, 38641)	0.2062792468281062
#   (0, 58299)	0.11355918868736861
#   (0, 2261)	0.140911774178889
#   (0, 39390)	0.11907123344715954
#   (0, 50721)	0.09190797940163037
#   (0, 29316)	0.10093917370354447
#   (0, 50915)	0.1343481728311918
#   (0, 12774)	0.12544427954397822
#   (0, 59243)	0.1300801610445509
#   (0, 48382)	0.10339358185033236
#   (0, 19887)	0.13281884272823927
#   (0, 22086)	0.10438761058719499
#   (0, 37970)	0.10142919482788752
#   (0, 4762)	0.14748820342184052
#   (0, 18010)	0.1348314953863925
#   :	:
#   (45464, 63541)	0.1233823724233346
#   (45464, 20136)	0.13613037415656817
#   (45464, 15665)	0.14870121148921367
#   (45464, 20467)	0.16775127520702973
#   (45465, 73642)	0.10753480162665091
#   (45465, 73035)	0.13408706904843892
#   (45465, 42386)	0.12682314802388575
#   (45465, 30464)	0.23372938747641966
#   (45465, 18224)	0.14003020730640697
#   (45465, 17521)	0.20194379723689698
#   (45465, 25954)	0.17463766681408405
#   (45465, 11595)	0.1495102584564939
#   (45465, 54915)	0.1771086986779744
#   (45465, 737)	0.19705855423130803
#   (45465, 23201)	0.18746398082285706
#   (45465, 527)	0.19373236541205788
#   (45465, 22484)	0.2870080183400214
#   (45465, 4292)	0.22205742077995708
#   (45465, 4818)	0.31187615002406843
#   (45465, 34190)	0.24149809503729772
#   (45465, 68819)	0.2275925581436693
#   (45465, 16083)	0.24240124102129873
#   (45465, 43160)	0.23659506958428508
#   (45465, 7505)	0.29153232978272675
#   (45465, 16765)	0.32377652198666534

# %%
k = 40
model = KMeans(n_clusters = k, init = 'k-means++',max_iter=100, n_init=1)
model.fit(features)
# Out:
# KMeans(max_iter=100, n_clusters=40, n_init=1)

# %%
df['cluster'] = model.labels_ 
df.head()
# Out:
#    id                        title  \
# 0   0                    Toy Story
# 1   1                      Jumanji
# 2   2             Grumpier Old Men
# 3   3            Waiting to Exhale
# 4   4  Father of the Bride Part II
#
#                                             overview  cluster
# 0  Led by Woody, Andy's toys live happily in his ...        8
# 1  When siblings Judy and Peter discover an encha...        8
# 2  A family wedding reignites the ancient feud be...       39
# 3  Cheated on, mistreated and stepped on, the wom...       12
# 4  Just when George Banks has recovered from his ...       26

# %%
df
# Out:
#           id                        title  \
# 0          0                    Toy Story
# 1          1                      Jumanji
# 2          2             Grumpier Old Men
# 3          3            Waiting to Exhale
# 4          4  Father of the Bride Part II
# ...      ...                          ...
# 45461  45461                       Subdue
# 45462  45462          Century of Birthing
# 45463  45463                     Betrayal
# 45464  45464             Satan Triumphant
# 45465  45465                     Queerama
#
#                                                 overview  cluster
# 0      Led by Woody, Andy's toys live happily in his ...        8
# 1      When siblings Judy and Peter discover an encha...        8
# 2      A family wedding reignites the ancient feud be...       39
# 3      Cheated on, mistreated and stepped on, the wom...       12
# 4      Just when George Banks has recovered from his ...       26
# ...                                                  ...      ...
# 45461        Rising and falling between a man and woman.       11
# 45462  An artist struggles to finish his work while a...        8
# 45463  When one of her hits goes wrong, a professiona...        8
# 45464  In a small town live two brothers, one a minis...        3
# 45465  50 years after decriminalisation of homosexual...        1
#
# [45466 rows x 4 columns]

# %%
clusters = df.groupby('cluster')    

for cluster in clusters.groups:
    f = open('cluster'+str(cluster)+ '.csv', 'w') # create csv file
    data = clusters.get_group(cluster)[['title','overview']] # get title and overview columns
    f.write(data.to_csv(index_label='id')) # set index to id
    f.close()

# %%
print("Cluster centroids: \n")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()
# Out:
# Cluster centroids:

# %%
for i in range(k):
    print("Cluster %d:" % i)
    for j in order_centroids[i, :10]: #print out 10 feature terms of each cluster
        print (' %s' % terms[j])
    print('------------')
# Out:
# Cluster 0:
#  year
#  old
#  boy
#  father
#  life
#  girl
#  family
#  new
#  son
#  mother
# ------------
# Cluster 1:
#  men
#  young
#  women
#  lives
#  story
#  life
#  woman
#  love
#  world
#  different
# ------------
# Cluster 2:
#  love
#  falls
#  story
#  young
#  fall
#  woman
#  life
#  man
#  meets
#  true
# ------------
# Cluster 3:
#  town
#  small
#  sheriff
#  local
#  new
#  life
#  people
#  young
#  family
#  home
# ------------
# Cluster 4:
#  just
#  band
#  rock
#  music
#  time
#  concert
#  new
#  like
#  life
#  world
# ------------
# Cluster 5:
#  overview
#  available
#  movie
#  plot
#  freaks
#  freakishly
#  freakish
#  freaking
#  freaked
#  freak
# ------------
# Cluster 6:
#  nan
#  ݣ1890
#  frazier
#  fraw
#  fray
#  frayed
#  fraying
#  frayn
#  frazer
#  frazzled
# ------------
# Cluster 7:
#  united
#  states
#  president
#  war
#  american
#  world
#  film
#  years
#  life
#  america
# ------------
# Cluster 8:
#  world
#  young
#  story
#  wife
#  time
#  people
#  new
#  finds
#  takes
#  help
# ------------
# Cluster 9:
#  college
#  student
#  students
#  professor
#  friends
#  life
#  campus
#  new
#  group
#  young
# ------------
# Cluster 10:
#  past
#  life
#  present
#  future
#  woman
#  man
#  young
#  years
#  finds
#  dark
# ------------
# Cluster 11:
#  woman
#  young
#  husband
#  man
#  life
#  finds
#  married
#  love
#  tries
#  beautiful
# ------------
# Cluster 12:
#  friends
#  best
#  life
#  time
#  family
#  lives
#  night
#  young
#  old
#  help
# ------------
# Cluster 13:
#  series
#  murders
#  events
#  film
#  mysterious
#  tv
#  films
#  time
#  story
#  young
# ------------
# Cluster 14:
#  film
#  directed
#  director
#  story
#  based
#  short
#  life
#  feature
#  films
#  time
# ------------
# Cluster 15:
#  york
#  new
#  city
#  young
#  life
#  world
#  love
#  story
#  man
#  home
# ------------
# Cluster 16:
#  christmas
#  santa
#  eve
#  claus
#  holiday
#  family
#  time
#  new
#  spirit
#  season
# ------------
# Cluster 17:
#  dead
#  body
#  man
#  end
#  young
#  wife
#  left
#  life
#  woman
#  finds
# ------------
# Cluster 18:
#  art
#  artist
#  life
#  world
#  work
#  film
#  artists
#  museum
#  documentary
#  new
# ------------
# Cluster 19:
#  play
#  based
#  game
#  stage
#  young
#  film
#  adaptation
#  comedy
#  life
#  story
# ------------
# Cluster 20:
#  cop
#  undercover
#  police
#  drug
#  gang
#  murder
#  crime
#  partner
#  criminal
#  tough
# ------------
# Cluster 21:
#  group
#  people
#  friends
#  young
#  world
#  try
#  soldiers
#  lives
#  small
#  time
# ------------
# Cluster 22:
#  documentary
#  film
#  feature
#  interviews
#  world
#  filmmaker
#  footage
#  american
#  length
#  life
# ------------
# Cluster 23:
#  book
#  based
#  comic
#  world
#  author
#  story
#  life
#  writer
#  young
#  film
# ------------
# Cluster 24:
#  man
#  young
#  wife
#  life
#  story
#  old
#  father
#  finds
#  world
#  love
# ------------
# Cluster 25:
#  life
#  story
#  world
#  young
#  day
#  new
#  time
#  years
#  lives
#  love
# ------------
# Cluster 26:
#  daughter
#  father
#  wife
#  young
#  love
#  family
#  man
#  son
#  life
#  mother
# ------------
# Cluster 27:
#  earth
#  planet
#  space
#  alien
#  aliens
#  crew
#  human
#  race
#  world
#  save
# ------------
# Cluster 28:
#  police
#  murder
#  detective
#  case
#  officer
#  crime
#  investigation
#  wife
#  inspector
#  young
# ------------
# Cluster 29:
#  island
#  remote
#  group
#  pacific
#  deserted
#  young
#  small
#  ship
#  soon
#  man
# ------------
# Cluster 30:
#  doctor
#  young
#  hospital
#  dr
#  wife
#  patients
#  love
#  life
#  woman
#  patient
# ------------
# Cluster 31:
#  prison
#  released
#  years
#  life
#  man
#  escape
#  inmates
#  crime
#  prisoners
#  inmate
# ------------
# Cluster 32:
#  war
#  world
#  ii
#  civil
#  american
#  german
#  soldiers
#  story
#  army
#  soldier
# ------------
# Cluster 33:
#  killer
#  serial
#  detective
#  police
#  victims
#  young
#  killing
#  case
#  catch
#  man
# ------------
# Cluster 34:
#  school
#  high
#  students
#  teacher
#  student
#  girls
#  new
#  friends
#  girl
#  class
# ------------
# Cluster 35:
#  mother
#  father
#  son
#  family
#  young
#  home
#  life
#  boy
#  death
#  single
# ------------
# Cluster 36:
#  movie
#  film
#  life
#  story
#  star
#  director
#  hollywood
#  tv
#  young
#  based
# ------------
# Cluster 37:
#  girl
#  young
#  love
#  teenage
#  father
#  boy
#  life
#  man
#  little
#  family
# ------------
# Cluster 38:
#  house
#  haunted
#  family
#  couple
#  young
#  old
#  home
#  new
#  wife
#  soon
# ------------
# Cluster 39:
#  family
#  home
#  life
#  father
#  son
#  young
#  man
#  story
#  new
#  brother
# ------------
